# %% [markdown]
# ## Import Libraries

# %%
import skimage.io as skio

# %% [markdown]
# ## Read Image

# %%
img = skio.imread('pyTrials/img.jpg')
img.shape
# Out:
# (720, 720, 3)

# %%
#!pip install cv2

# %%
skio.imshow(img)
